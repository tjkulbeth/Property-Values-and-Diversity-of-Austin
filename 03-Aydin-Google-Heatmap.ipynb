# %%
# Dependencies
import pandas as pd
import requests
import json
import gmaps
# Google developer API key
from config import gkey

merge_data = pd.read_csv('data_sources/merge_data.csv')

# %%
#Filter used data by 2017
merge_data_n=merge_data[merge_data["Year"]==2017]
merge_data_n=merge_data.groupby(["City"]).mean()
merge_data_n["city"]=merge_data_n.index
merge_data_n["Diversity Index"]=merge_data_n["Diversity Index"]*100

# %%
# latitude and longitude
merge_data_n["Lat"]=0.001
merge_data_n["Lng"]=0.001
for  row in merge_data_n["city"]:
    target_city=row
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(target_city+", Texas", gkey)
    
    # Run a request to endpoint and convert result to json
    geo_data = requests.get(target_url).json()
    
    # Print the json
    print(geo_data)
   
    # Extract latitude and longitude
    lat = geo_data["results"][0]["geometry"]["location"]["lat"]
    lng = geo_data["results"][0]["geometry"]["location"]["lng"]
    merge_data_n["Lat"][row]=lat
    merge_data_n["Lng"][row]=lng
#     Print the latitude and longitude
    print('''
        City: {0}
        Latitude: {1}
        Longitude: {2}
        '''.format(target_city, lat, lng))
# Out:
# {'results': [{'address_components': [{'long_name': 'Austin', 'short_name': 'Austin', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Austin, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.5168629, 'lng': -97.5684199}, 'southwest': {'lat': 30.0986589, 'lng': -97.9383829}}, 'location': {'lat': 30.267153, 'lng': -97.7430608}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.5168629, 'lng': -97.5684199}, 'southwest': {'lat': 30.0986589, 'lng': -97.9383829}}}, 'place_id': 'ChIJLwPMoJm1RIYRetVp1EtGm10', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Austin
#         Latitude: 30.267153
#         Longitude: -97.7430608
# C:\Users\Billy\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Billy\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# {'results': [{'address_components': [{'long_name': 'Bastrop', 'short_name': 'Bastrop', 'types': ['locality', 'political']}, {'long_name': 'Bastrop County', 'short_name': 'Bastrop County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78602', 'short_name': '78602', 'types': ['postal_code']}], 'formatted_address': 'Bastrop, TX 78602, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.1377119, 'lng': -97.2775851}, 'southwest': {'lat': 30.0883561, 'lng': -97.36482490000002}}, 'location': {'lat': 30.1104947, 'lng': -97.3152701}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.1377119, 'lng': -97.2775851}, 'southwest': {'lat': 30.0883561, 'lng': -97.36482490000002}}}, 'place_id': 'ChIJadvR6FuaRIYRYNmtW2Y8DTQ', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Bastrop
#         Latitude: 30.1104947
#         Longitude: -97.3152701
#
# {'results': [{'address_components': [{'long_name': 'Bee Cave', 'short_name': 'Bee Cave', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Bee Cave, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.3281754, 'lng': -97.917086}, 'southwest': {'lat': 30.288781, 'lng': -98.00216669999999}}, 'location': {'lat': 30.306098, 'lng': -97.9523768}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.3281754, 'lng': -97.917086}, 'southwest': {'lat': 30.288781, 'lng': -98.00216669999999}}}, 'place_id': 'ChIJ4xVDx_Q3W4YRbZ21jYSINBE', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Bee Cave
#         Latitude: 30.306098
#         Longitude: -97.9523768
#
# {'results': [{'address_components': [{'long_name': 'Buda', 'short_name': 'Buda', 'types': ['locality', 'political']}, {'long_name': 'Hays County', 'short_name': 'Hays County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78610', 'short_name': '78610', 'types': ['postal_code']}], 'formatted_address': 'Buda, TX 78610, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.113591, 'lng': -97.810867}, 'southwest': {'lat': 30.0645159, 'lng': -97.87254689999999}}, 'location': {'lat': 30.0817231, 'lng': -97.8428927}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.113591, 'lng': -97.810867}, 'southwest': {'lat': 30.0645159, 'lng': -97.87254689999999}}}, 'place_id': 'ChIJ9SXf8qVOW4YRDAZXz7cO5J8', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Buda
#         Latitude: 30.0817231
#         Longitude: -97.8428927
#
# {'results': [{'address_components': [{'long_name': 'Cedar Creek', 'short_name': 'Cedar Creek', 'types': ['locality', 'political']}, {'long_name': 'Bastrop County', 'short_name': 'Bastrop County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Cedar Creek, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.1179069, 'lng': -97.4914326}, 'southwest': {'lat': 30.0799805, 'lng': -97.5590608}}, 'location': {'lat': 30.0873153, 'lng': -97.501432}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.1179069, 'lng': -97.4914326}, 'southwest': {'lat': 30.0799805, 'lng': -97.5590608}}}, 'place_id': 'ChIJuQoxBgujRIYRvZUrZifnaSU', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Cedar Creek
#         Latitude: 30.0873153
#         Longitude: -97.501432
#
# {'results': [{'address_components': [{'long_name': 'Cedar Park', 'short_name': 'Cedar Park', 'types': ['locality', 'political']}, {'long_name': 'Williamson County', 'short_name': 'Williamson County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Cedar Park, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.553367, 'lng': -97.74521279999999}, 'southwest': {'lat': 30.455388, 'lng': -97.88851000000001}}, 'location': {'lat': 30.505198, 'lng': -97.8202888}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.553367, 'lng': -97.74521279999999}, 'southwest': {'lat': 30.455388, 'lng': -97.88851000000001}}}, 'place_id': 'ChIJ1Zl9vhctW4YR_zkVv4ahPXY', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Cedar Park
#         Latitude: 30.505198
#         Longitude: -97.8202888
#
# {'results': [{'address_components': [{'long_name': 'Driftwood', 'short_name': 'Driftwood', 'types': ['locality', 'political']}, {'long_name': 'Hays County', 'short_name': 'Hays County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78619', 'short_name': '78619', 'types': ['postal_code']}], 'formatted_address': 'Driftwood, TX 78619, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.146887, 'lng': -98.028065}, 'southwest': {'lat': 30.1182069, 'lng': -98.04478859999999}}, 'location': {'lat': 30.123275, 'lng': -98.0315889}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.146887, 'lng': -98.028065}, 'southwest': {'lat': 30.1182069, 'lng': -98.04478859999999}}}, 'place_id': 'ChIJ99V4YpZEW4YRfMqg1B9GY4A', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Driftwood
#         Latitude: 30.123275
#         Longitude: -98.0315889
#
# {'results': [{'address_components': [{'long_name': 'Dripping Springs', 'short_name': 'Dripping Springs', 'types': ['locality', 'political']}, {'long_name': 'Hays County', 'short_name': 'Hays County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Dripping Springs, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.2122539, 'lng': -98.06366}, 'southwest': {'lat': 30.158165, 'lng': -98.1112589}}, 'location': {'lat': 30.1902067, 'lng': -98.0866781}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.2122539, 'lng': -98.06366}, 'southwest': {'lat': 30.158165, 'lng': -98.1112589}}}, 'place_id': 'ChIJKWt9oIc_W4YRa5zaN5FiLRU', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Dripping Springs
#         Latitude: 30.1902067
#         Longitude: -98.0866781
#
# {'results': [{'address_components': [{'long_name': 'Elgin', 'short_name': 'Elgin', 'types': ['locality', 'political']}, {'long_name': 'Bastrop County', 'short_name': 'Bastrop County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78621', 'short_name': '78621', 'types': ['postal_code']}], 'formatted_address': 'Elgin, TX 78621, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.378306, 'lng': -97.357162}, 'southwest': {'lat': 30.3320339, 'lng': -97.4270968}}, 'location': {'lat': 30.3496528, 'lng': -97.3702735}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.378306, 'lng': -97.357162}, 'southwest': {'lat': 30.3320339, 'lng': -97.4270968}}}, 'place_id': 'ChIJM3hn7RDrRIYROw3XfhQqn9w', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Elgin
#         Latitude: 30.3496528
#         Longitude: -97.3702735
# {'results': [{'address_components': [{'long_name': 'Georgetown', 'short_name': 'Georgetown', 'types': ['locality', 'political']}, {'long_name': 'Williamson County', 'short_name': 'Williamson County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Georgetown, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.742566, 'lng': -97.585174}, 'southwest': {'lat': 30.570766, 'lng': -97.832725}}, 'location': {'lat': 30.6332618, 'lng': -97.6779842}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.742566, 'lng': -97.585174}, 'southwest': {'lat': 30.570766, 'lng': -97.832725}}}, 'place_id': 'ChIJ3_vaVP3VRIYRCTrAlN407GE', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Georgetown
#         Latitude: 30.6332618
#         Longitude: -97.6779842
#
# {'results': [{'address_components': [{'long_name': 'Hutto', 'short_name': 'Hutto', 'types': ['locality', 'political']}, {'long_name': 'Williamson County', 'short_name': 'Williamson County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78634', 'short_name': '78634', 'types': ['postal_code']}], 'formatted_address': 'Hutto, TX 78634, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.57105, 'lng': -97.516142}, 'southwest': {'lat': 30.5073051, 'lng': -97.583433}}, 'location': {'lat': 30.54269949999999, 'lng': -97.5466702}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.57105, 'lng': -97.516142}, 'southwest': {'lat': 30.5073051, 'lng': -97.583433}}}, 'place_id': 'ChIJSQ3sRrLCRIYRifh7eyJcRcg', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Hutto
#         Latitude: 30.54269949999999
#         Longitude: -97.5466702
#
# {'results': [{'address_components': [{'long_name': 'Kyle', 'short_name': 'Kyle', 'types': ['locality', 'political']}, {'long_name': 'Hays County', 'short_name': 'Hays County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Kyle, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.0563709, 'lng': -97.824348}, 'southwest': {'lat': 29.9431801, 'lng': -97.909599}}, 'location': {'lat': 29.9891052, 'lng': -97.87722670000001}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.0563709, 'lng': -97.824348}, 'southwest': {'lat': 29.9431801, 'lng': -97.909599}}}, 'place_id': 'ChIJ_RKeSnxQW4YRdrZvcekI9Ug', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Kyle
#         Latitude: 29.9891052
#         Longitude: -97.87722670000001
#
# {'results': [{'address_components': [{'long_name': 'Lago Vista', 'short_name': 'Lago Vista', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78645', 'short_name': '78645', 'types': ['postal_code']}], 'formatted_address': 'Lago Vista, TX 78645, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.503704, 'lng': -97.9551939}, 'southwest': {'lat': 30.415384, 'lng': -98.03474}}, 'location': {'lat': 30.4601975, 'lng': -97.98834769999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.503704, 'lng': -97.9551939}, 'southwest': {'lat': 30.415384, 'lng': -98.03474}}}, 'place_id': 'ChIJySvgJtE6W4YRWOcIJJvvKLU', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Lago Vista
#         Latitude: 30.4601975
#         Longitude: -97.98834769999999
#
# {'results': [{'address_components': [{'long_name': 'Lakeway', 'short_name': 'Lakeway', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Lakeway, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.385895, 'lng': -97.9425211}, 'southwest': {'lat': 30.3179883, 'lng': -98.0246116}}, 'location': {'lat': 30.3679788, 'lng': -97.99167899999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.385895, 'lng': -97.9425211}, 'southwest': {'lat': 30.3179883, 'lng': -98.0246116}}}, 'place_id': 'ChIJSz9WADA4W4YRubHM5_5TnkE', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Lakeway
#         Latitude: 30.3679788
#         Longitude: -97.99167899999999
#
# {'results': [{'address_components': [{'long_name': 'Leander', 'short_name': 'Leander', 'types': ['locality', 'political']}, {'long_name': 'Williamson County', 'short_name': 'Williamson County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78641', 'short_name': '78641', 'types': ['postal_code']}], 'formatted_address': 'Leander, TX 78641, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.62407, 'lng': -97.792327}, 'southwest': {'lat': 30.515724, 'lng': -97.91814389999999}}, 'location': {'lat': 30.5788055, 'lng': -97.8530686}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.62407, 'lng': -97.792327}, 'southwest': {'lat': 30.515724, 'lng': -97.91814389999999}}}, 'place_id': 'ChIJdRgZBtUqW4YRliS2WqUef30', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Leander
#         Latitude: 30.5788055
#         Longitude: -97.8530686
#
# {'results': [{'address_components': [{'long_name': 'Liberty Hill', 'short_name': 'Liberty Hill', 'types': ['locality', 'political']}, {'long_name': 'Williamson County', 'short_name': 'Williamson County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78642', 'short_name': '78642', 'types': ['postal_code']}], 'formatted_address': 'Liberty Hill, TX 78642, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.6778199, 'lng': -97.858074}, 'southwest': {'lat': 30.6475789, 'lng': -97.944643}}, 'location': {'lat': 30.6649119, 'lng': -97.9225161}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.6778199, 'lng': -97.858074}, 'southwest': {'lat': 30.6475789, 'lng': -97.944643}}}, 'place_id': 'ChIJN4qtPzPeRIYRpCU0Kl_k69k', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Liberty Hill
#         Latitude: 30.6649119
#         Longitude: -97.9225161
#
# {'results': [{'address_components': [{'long_name': 'Lockhart', 'short_name': 'Lockhart', 'types': ['locality', 'political']}, {'long_name': 'Caldwell County', 'short_name': 'Caldwell County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78644', 'short_name': '78644', 'types': ['postal_code']}], 'formatted_address': 'Lockhart, TX 78644, USA', 'geometry': {'bounds': {'northeast': {'lat': 29.9244709, 'lng': -97.62464390000001}, 'southwest': {'lat': 29.840644, 'lng': -97.72831509999999}}, 'location': {'lat': 29.8849441, 'lng': -97.6699996}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 29.9244709, 'lng': -97.62464390000001}, 'southwest': {'lat': 29.840644, 'lng': -97.72831509999999}}}, 'place_id': 'ChIJBTaxdVRWQ4YRFOFfLUFSM4U', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Lockhart
#         Latitude: 29.8849441
#         Longitude: -97.6699996
# {'results': [{'address_components': [{'long_name': 'Luling', 'short_name': 'Luling', 'types': ['locality', 'political']}, {'long_name': 'Caldwell County', 'short_name': 'Caldwell County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78648', 'short_name': '78648', 'types': ['postal_code']}], 'formatted_address': 'Luling, TX 78648, USA', 'geometry': {'bounds': {'northeast': {'lat': 29.7048079, 'lng': -97.58989389999999}, 'southwest': {'lat': 29.64521, 'lng': -97.6724079}}, 'location': {'lat': 29.68050659999999, 'lng': -97.647498}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 29.7048079, 'lng': -97.58989389999999}, 'southwest': {'lat': 29.64521, 'lng': -97.6724079}}}, 'place_id': 'ChIJNWByMiJPQ4YRr3UhGYDLL-Q', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Luling
#         Latitude: 29.68050659999999
#         Longitude: -97.647498
#
# {'results': [{'address_components': [{'long_name': 'Manor', 'short_name': 'Manor', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78653', 'short_name': '78653', 'types': ['postal_code']}], 'formatted_address': 'Manor, TX 78653, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.3776169, 'lng': -97.5038121}, 'southwest': {'lat': 30.3273461, 'lng': -97.574957}}, 'location': {'lat': 30.3407629, 'lng': -97.55694559999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.3776169, 'lng': -97.5038121}, 'southwest': {'lat': 30.3273461, 'lng': -97.574957}}}, 'place_id': 'ChIJ26TSh8TARIYRBzQtjIzkhnQ', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Manor
#         Latitude: 30.3407629
#         Longitude: -97.55694559999999
#
# {'results': [{'address_components': [{'long_name': 'Martindale', 'short_name': 'Martindale', 'types': ['locality', 'political']}, {'long_name': 'Caldwell County', 'short_name': 'Caldwell County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78655', 'short_name': '78655', 'types': ['postal_code']}], 'formatted_address': 'Martindale, TX 78655, USA', 'geometry': {'bounds': {'northeast': {'lat': 29.866629, 'lng': -97.8020559}, 'southwest': {'lat': 29.8288501, 'lng': -97.87017980000002}}, 'location': {'lat': 29.8454994, 'lng': -97.8408364}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 29.866629, 'lng': -97.8020559}, 'southwest': {'lat': 29.8288501, 'lng': -97.87017980000002}}}, 'place_id': 'ChIJMx46X46rXIYRmVLMRfX8PsA', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Martindale
#         Latitude: 29.8454994
#         Longitude: -97.8408364
#
# {'results': [{'address_components': [{'long_name': 'Paige', 'short_name': 'Paige', 'types': ['locality', 'political']}, {'long_name': 'Bastrop County', 'short_name': 'Bastrop County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78659', 'short_name': '78659', 'types': ['postal_code']}], 'formatted_address': 'Paige, TX 78659, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.2184041, 'lng': -97.1076598}, 'southwest': {'lat': 30.208095, 'lng': -97.1283492}}, 'location': {'lat': 30.2117727, 'lng': -97.11457879999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.2184041, 'lng': -97.1076598}, 'southwest': {'lat': 30.208095, 'lng': -97.1283492}}}, 'place_id': 'ChIJKZXmMLmJRIYRXSa0FTGLk7w', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Paige
#         Latitude: 30.2117727
#         Longitude: -97.11457879999999
#
# {'results': [{'address_components': [{'long_name': 'Pflugerville', 'short_name': 'Pflugerville', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Pflugerville, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.5005012, 'lng': -97.5031364}, 'southwest': {'lat': 30.3814219, 'lng': -97.6688245}}, 'location': {'lat': 30.4548451, 'lng': -97.6222665}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.5005012, 'lng': -97.5031364}, 'southwest': {'lat': 30.3814219, 'lng': -97.6688245}}}, 'place_id': 'ChIJT4Rx_7TNRIYR4Mu-ZHsEEcg', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Pflugerville
#         Latitude: 30.4548451
#         Longitude: -97.6222665
#
# {'results': [{'address_components': [{'long_name': 'Round Rock', 'short_name': 'Round Rock', 'types': ['locality', 'political']}, {'long_name': 'Williamson County', 'short_name': 'Williamson County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Round Rock, TX, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.584496, 'lng': -97.590564}, 'southwest': {'lat': 30.4684358, 'lng': -97.755473}}, 'location': {'lat': 30.5082551, 'lng': -97.678896}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.584496, 'lng': -97.590564}, 'southwest': {'lat': 30.4684358, 'lng': -97.755473}}}, 'place_id': 'ChIJ5yIt7aTRRIYREEvg7VlyIQc', 'types': ['locality', 'political']}], 'status': 'OK'}
#
#         City: Round Rock
#         Latitude: 30.5082551
#         Longitude: -97.678896
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     298             else:
# --> 299                 raise SocketError(str(e))
#     300         except OpenSSL.SSL.ZeroReturnError as e:
#
# OSError: (10060, 'WSAETIMEDOUT')
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\http\client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\http\client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\http\client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     298             else:
# --> 299                 raise SocketError(str(e))
#     300         except OpenSSL.SSL.ZeroReturnError as e:
#
# ProtocolError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')",))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-12-2dbb3cde9fa6> in <module>
#       8
#       9     # Run a request to endpoint and convert result to json
# ---> 10     geo_data = requests.get(target_url).json()
#      11
#      12     # Print the json
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\AppData\Local\conda\conda\envs\bh6project1\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')",))

# %% [markdown]
#  For the heat map, I used the merged data from Zillow and Census .I filtered merged data by 2017 to understand how diverse is Austin and surrounding areas.I added latitude and longitude to my data chart as well to use heatmap. In short, Round Rock, Pflugerville, Leander, Buda, Mountain City, San Marcos and part of the Cedar Park have diverse population compare to rest of the Austin and surrounding areas.

# %%
# Plot Heatmap
weight=locations = merge_data_n["Diversity Index"].astype(float)
locations = merge_data_n[["Lat", "Lng"]].astype(float)
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, 
                                 dissipating=False, max_intensity=80, weights=weight,
                                 point_radius=0.15)
# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
